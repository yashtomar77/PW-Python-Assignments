# %% [markdown]
# # MATPLOTLIB ASSIGNMENT

# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is a popular Python library for creating static, animated, and interactive visualizations in a variety of formats. It is often used for creating 2D and basic 3D plots, charts, and graphs to visualize data in a clear and understandable way.

# %% [markdown]
# # Why is it used?

# %% [markdown]
# Matplotlib is used to visually represent data in a graphical format. It helps users to understand complex datasets by presenting them in a more comprehensible form, making it easier to identify patterns, trends, and relationships within the data.

# %% [markdown]
# # Five Plots using Pyplot module in Matplotlib:

# %% [markdown]
# The pyplot module in Matplotlib provides a simple interface for creating a variety of plots. Here are five types of plots that you can create using the pyplot module:
#
# 1.Line Plot:
# plt.plot(x, y)
#
# 2.Bar Plot:
# plt.bar(categories, values)
#
# 3.Scatter Plot:
# plt.scatter(x, y)
#
# 4.Histogram:
# plt.hist(data, bins=30, edgecolor='black')
#
# 5.Pie Chart:
# plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel('X Axis')
plt.ylabel('Y Label')
plt.show()

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:

# %% [markdown]
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import matplotlib.pyplot as plt
import numpy as np


x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])


x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])


x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])


x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Creating subplots
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, plot position 1
plt.plot(x1, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)  # 2 rows, 2 columns, plot position 2
plt.plot(x2, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)  # 2 rows, 2 columns, plot position 3
plt.plot(x3, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)  # 2 rows, 2 columns, plot position 4
plt.plot(x4, y4)
plt.title('Line 4')

# Adjust layout for better appearance
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It summarizes key statistical measures, such as the median, quartiles, and potential outliers, providing a visual tool for understanding the central tendency and spread of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)
data = [box1,box2]
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot for Box 1 and Box 2')
plt.ylabel('Values')
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot for Box 1 and Box 2')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')
